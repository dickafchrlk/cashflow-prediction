# %%
import pandas as pd

df = pd.read_csv("../data/cleaned/JPNGKAS_clean.csv")

print(df.info())

print(df.isnull().sum())

print(df.duplicated().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   TANGGAL                      649 non-null    str
#  1   URAIAN                       419 non-null    str
#  2   QRIS BNI                     81 non-null     str
#  3   DBT_BANK_BPR_SOREANG         648 non-null    float64
#  4   DBT_BANK_BJB                 648 non-null    float64
#  5   PIUTANG                      649 non-null    int64
#  6   KANTIN                       648 non-null    float64
#  7   PHOTOCOPY                    648 non-null    float64
#  8   OPERASIONAL PC               648 non-null    float64
#  9   BINGKISAN                    648 non-null    float64
#  10  PEMBELIAN_B_POKOK            648 non-null    float64
#  11  PEMBELIAN B SANDANG          648 non-null    float64
#  12  PEMBAYARAN B POKOK           648 non-null    float64
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/cleaned/JPNKAS_clean.csv")

print(df.info())

print(df.isnull().sum())

print(df.duplicated().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   TANGGAL                360 non-null    str
#  1   URAIAN                 352 non-null    str
#  2   DBT_KAS                361 non-null    int64
#  3   K_QRIS BNI             356 non-null    float64
#  4   BANK BJB               355 non-null    float64
#  5   PHOTOCOPY              356 non-null    float64
#  6   KANTI N                356 non-null    float64
#  7   K_PENJ_  B_ POKOKP     356 non-null    float64
#  8   K_REALISASI_ B_ POKOK  356 non-null    float64
#  9   K_DANA_ BINGKISAN      356 non-null    float64
#  10  K_RETUR_ B_ POKOK      356 non-null    float64
#  11  K_VOUCHER_ BELANJA     356 non-null    float64
#  12  HUTANG TOKO            356 non-null    float64
#  13  BULAN                  355 non-null    str
# dtypes: float64(10), int64(1), str(3)
# ...
